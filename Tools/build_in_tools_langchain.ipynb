# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('ls')

print(results)
# Out:
# Executing command:
#  ls
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from langchain_community.tools import DuckDuckGoSearchRun

SearchResults = DuckDuckGoSearchRun()

result = SearchResults.invoke('ipl winner 2025')

print(result)
# Out:
# IPL 2025 Winner Season 18: Prize Money and Score ... Tags: IPL 2025 Winner , IPL 2025 Winner season ... This IPL 2025 series will stand out for the ... In this article we are going to discuss team strengths, weaknesses, key players and the strategies to predict the probable winner of IPL 2025 . IPL 2025 Winner Prediction: Who Will Win IPL Trophy This Year? Check Out Astrology Predictions! ... As the Indian Premier League ( IPL ) 2025 season ... The IPL 2025 winners to take home a massive ... The IPL 2025 winners took home a massive Rs 20 crore, while the runners-up would earn Rs 13 crore. IPL Winner 2025 : The thrilling journey of the Indian Premier League ( IPL ) 2025 finally concluded on June 3, 2025 , at the Narendra Modi Stadium in ...
